# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeRuy97/BootcampDataScienceAlura/blob/main/mod1Aula2BootcampAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AULA 01 MOD 01

# %% [markdown]
# # AULA 02 MOD 01

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/tabela.csv", encoding="ISO-8859-1",
                    skiprows = 3, sep =";", skipfooter = 12,
                    thousands = ".", decimal = ",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federaï¿½ï¿½o 1992/Mar  ...     2020/Ago         Total
# 0            11 Rondï¿½nia        -  ...   3556381.57  9.291297e+08
# 1                  12 Acre        -  ...            -  4.206680e+08
# 2              13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3               14 Roraima        -  ...   1524478.04  3.050109e+08
# 4                15 Parï¿½        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
#Eh necessario passar dois colchetes ao passar mais de uma coluna
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#       2008/Ago     2008/Set
# 0   2938286.29   2843930.91
# 1   1886871.84   2084884.80
# 2   8331763.97   8148089.92
# 3   1045291.11   1003740.89
# 4  23259148.28  23667690.01

# %%
#A media ignora os valores vazios antes que estao antes de 2007
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
#Ao fazer as colunas usaveis excluimos a unidade da federacao.
#Precisamos entao adiciona-la dnv, porém, precisamos transformar em lista
#antes para podermos inseri-la pois o index eh uma serie imutavel
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federaï¿½ï¿½o")
colunas_usaveis
# Out:
# ['Unidade da Federaï¿½ï¿½o',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis].head()
usaveis
# Out:
#   Unidade da Federaï¿½ï¿½o   2007/Ago  ...     2020/Jul         Total
# 0            11 Rondï¿½nia    4209.37  ...   7407388.24  9.291297e+08
# 1                  12 Acre   10470.07  ...   1163813.08  4.206680e+08
# 2              13 Amazonas   35752.72  ...  13358514.02  1.771655e+09
# 3               14 Roraima    4785.91  ...   2739498.41  3.050109e+08
# 4                15 Parï¿½  181159.29  ...  27618727.51  4.437116e+09
#
# [5 rows x 158 columns]

# %%
#Nota-se que o index está como um número (0,1,2...etc) e não como a unidade
#da federação, então usa-se set_index("Unidade da Federação")
usaveis.set_index("Unidade da Federaï¿½ï¿½o")
# Out:
#                            2007/Ago   2007/Set  ...     2020/Jul         Total
# Unidade da Federaï¿½ï¿½o                        ...
# 11 Rondï¿½nia               4209.37   16397.03  ...   7407388.24  9.291297e+08
# 12 Acre                    10470.07   14001.71  ...   1163813.08  4.206680e+08
# 13 Amazonas                35752.72   45570.64  ...  13358514.02  1.771655e+09
# 14 Roraima                  4785.91   11858.63  ...   2739498.41  3.050109e+08
# 15 Parï¿½                 181159.29  433414.74  ...  27618727.51  4.437116e+09
#
# [5 rows x 157 columns]

# %%
#Para ver uma coluna só
usaveis["2019/Ago"].head()
# Out:
# 0     8909111.89
# 1     2981072.98
# 2    16493719.52
# 3     3181321.82
# 4    36462011.47
# Name: 2019/Ago, dtype: float64

# %%
#Para localizar uma linha cujo indice é Acre
#O erro no arquivo nos impede de ver, mas funcionaria
usaveis.loc["12 Acre"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-10133f4b7ae1> in <module>()
#       1 #Para localizar uma linha cujo indice é Acre
# ----> 2 usaveis.loc[["12 Acre"]]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ...

# %%
#Plotar usaveis em um tamanho 12 por 6 com uma transposição T (as colunas viram
#os estados e as linhas os valores)
usaveis.T.plot(figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-b1bfa70ee407> in <module>()
#       1 #Plotar usaveis em um tamanho 12 por 6 com uma transposição T (as colunas viram
#       2 #os estados e as linhas os valores)
# ----> 3 usaveis.T.plot(figsize=(10,6))
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
# ...

# %%
#Precisamos remover a linha total para poder plotar um gráfico melhor
#"Procure no eixo 1 (eixo da coluna) a linha total"
usaveis.drop("Total",axis = 1)

# %% [markdown]
# Refazer aula quando o TABNET voltar

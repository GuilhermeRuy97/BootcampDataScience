# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeRuy97/Estudos-DataScience/blob/main/m%C3%B3dulo_1_e_2_Bootcamp_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AULA 01 MOD 01
# -Aquisição e leitura de dados reais

# %% [markdown]
# Caderno de exploração de dados datasus de 2008 em diante

# %%
import pandas as pd

# %%
#Neste caso, usa-se o enconding ISO para representar o padrão UTF-8, skiprows = 3
#para ignorar as 3 primeiras linhas, skipfooter para ignorar as ultimas 12;
#Usa-se o separador como ";" em vez de "," ;
#Usa-se thousands = "." para mostrar o separador de milhares;
#Usa-se decimal = "," para mostrar o separador de decimal do arquivo como "," .


dados = pd.read_csv("/content/A151346189_28_143_208.csv", encoding="ISO-8859-1",
                    skiprows = 3, sep = ";", skipfooter = 12,
                    thousands=".", decimal=",")

dados.head()  #primeiras 5 linhas
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
dados.tail()  #ultimas 5 linhas
# Out:
#      Unidade da Federação     2008/Jan  ...      2020/Ago         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  101374341.51  1.195865e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...   19241624.02  2.172158e+09
# 24         51 Mato Grosso   4795299.01  ...   17790649.87  2.036924e+09
# 25               52 Goiás  15310637.29  ...   43984702.05  4.657350e+09
# 26    53 Distrito Federal   4745919.19  ...   26526196.39  2.429933e+09
#
# [5 rows x 154 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %%
#Média

dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Abr    4.101366e+07
# 2020/Mai    4.419363e+07
# 2020/Jun    4.732999e+07
# 2020/Jul    5.449551e+07
# Total       5.993732e+09
# Length: 151, dtype: float64

# %%
#Troca o formato de apresentacao cientifico para com 2 casas decimais depois do "."

pd.options.display.float_format= "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
#Acessando os dados de agosto de 2008 (que no caso é uma série)

dados["2008/Ago"]
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
#Gráfico de gasto por unidade federativa

dados.plot(x = "Unidade da Federação",y = "2008/Ago")

# %%
#Porém, o gráfico de linhas não é adequado para essa situação;
#Para mudar para gráfico de barra, usa-se kind="bar";
#Usa-se figsize para alterar o tamanho da figura.

dados.plot(x = "Unidade da Federação",y = "2008/Ago", kind = "bar", figsize = (10,7))

# %%
#Vamos importar outra biblioteca gráfica para poder utilizar melhor dos argumentos do gráfico
import matplotlib.pyplot as plt

#Biblioteca para mudar o formato dos eixos
import matplotlib.ticker as ticker

#ax = axis, ou seja, eixo X
ax = dados.plot(x = "Unidade da Federação",y = "2020/Jul", kind = "bar", figsize = (10,7))

#Usamos um set para o formato ser um formato float com o separador de milhares como ","
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

#Adicionando um título
plt.title("Valor total de processamento para o mês de Julho segundo Unidade da Federação")

#Mostrando o gráfico
plt.show()

# %% [markdown]
# # AULA 02 MOD 01
# -Primeiras visualizações de dados

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A160324189_28_143_208.csv", encoding="ISO-8859-1",
                    skiprows = 3, sep =";", skipfooter = 12,
                    thousands = ".", decimal = ",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
#É necessario passar dois colchetes ao passar mais de uma coluna

dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
#A média ignora os valores vazios que estao antes de 2007
#pois ela ignora os valorez vazios. No caso, 2007 começa a ter todos os valores.

dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
#Ao fazer as colunas usaveis excluimos a unidade da federacao;
#Precisamos adiciona-la dnv, porém, precisamos transforma-la em lista
#antes para que possamos inseri-la, pois o index eh uma serie imutavel.

colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
#Nota-se que o index está como um número (0,1,2...etc) e não como a unidade
#da federação, então usa-se set_index("Unidade da Federação").

usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   7407388.24   929129659.72
# 12 Acre                  10470.07   14001.71  ...   1163813.08   420668039.63
# 13 Amazonas              35752.72   45570.64  ...  13358514.02  1771654871.23
# 14 Roraima                4785.91   11858.63  ...   2739498.41   305010883.18
# 15 Pará                 181159.29  433414.74  ...  27618727.51  4437115730.71
# 16 Amapá                 33672.74  104822.98  ...   2155083.37   291637984.75
# 17 Tocantins              4113.76   76633.06  ...   4489665.87   999998621.85
# 21 Maranhão             385330.18 1018352.93  ...  24374205.15  3632860959.84
# 22 Piauí                220788.25  353468.67  ...  18019214.49  2130616492.35
# 23 Ceará                357904.65  572356.18  ...  30809221.22  6197357245.98
# ...

# %%
#Para ver uma coluna só

usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
#Para localizar uma linha cujo indice é Acre;
#O .loc é utilizado para dados como parametro, já o .iloc busca por indices.

usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
#Exemplo de transposição (as linhas viram colunas e vice versa)

usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
#Plotarndo usaveis em um tamanho 12 por 6 com uma transposição T (as colunas viram
#os estados e as linhas os valores)

usaveis.T.plot(figsize=(10,6))

# %%
#Precisamos remover a linha total para poder plotar um gráfico melhor;
#"Procure no eixo 1 (eixo da coluna) a linha total".

usaveis = usaveis.drop("Total", axis = 1)
usaveis.head
# Out:
# <bound method NDFrame.head of                          2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   9193593.76   7407388.24
# 12 Acre                  10470.07   14001.71  ...   2199920.70   1163813.08
# 13 Amazonas              35752.72   45570.64  ...  17509334.66  13358514.02
# 14 Roraima                4785.91   11858.63  ...   3216466.51   2739498.41
# 15 Pará                 181159.29  433414.74  ...  35396030.78  27618727.51
# 16 Amapá                 33672.74  104822.98  ...   2699492.23   2155083.37
# 17 Tocantins              4113.76   76633.06  ...   5018138.13   4489665.87
# 21 Maranhão             385330.18 1018352.93  ...  31128144.66  24374205.15
# 22 Piauí                220788.25  353468.67  ...  15375523.59  18019214.49
# 23 Ceará                357904.65  572356.18  ...  42146555.81  30809221.22
# ...

# %%
#usaveis.T.plot(figsize=(10,6))

#Adicionando quadriculado no gráfico
#plt.grid(True)

#Posicionando a legenda para fora do gráfico
#plt.legend(loc = 'upper right', bbox_to_anchor = (1.3, 1.0))


# O .plot retona um objeto que representa os eixos do gráfico
# aqui salvamos esse objeto em ax para futuras configurações
ax = usaveis.T.plot(figsize=(10,6))

# A partir do ax configuramos a posição da legenda com o legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4) # upper center posicionar no meio e o bbox_to_anchor ajustar posição e ncol = número de colunas

# %%
#Desafio: Mudar a palete de cores

import numpy as np
from matplotlib import cm

color = cm.gist_rainbow(np.linspace(.0, 1, 27)) # Cria uma lista de cores baseada na paleta gist_rainbow do matplotlib usando numpy

#plt.style.use('tableau-colorblind10') #acessivel para 10 cores 
ax = usaveis.T.plot(figsize=(14,7), color=color)
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4)
#ax = usaveis.T.plot(figsize=(10,6), colormap='tab20b')

# %% [markdown]
# # AULA 03 MOD 01
# -Manipulação de dados

# %%
#Plotar os 27 estados no gráfico torna inviável a leitura do gráfico;
#Vamos escolher apenas 5 estados por ordem de gasto (poderia ser aleatório por ex.);
#Escolhendo os cinco primeiros(1,2,3,4).

usaveis.T.columns[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
#Utilizar usaveis.T.columns pode ser semelhante a escolher os index

usaveis.index[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[0:5].T.plot(figsize=(10,6))

# %%
#Criando uma amostra aleatoria (no caso com n = 7);
#Cada vez que se rodamos o código, um resultado diferente é mostrado.

usaveis.sample(n = 7)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 42 Santa Catarina     693955.05 1092964.12  ...  56503747.99  51764534.76
# 33 Rio de Janeiro     469469.34  921646.57  ...  77604925.21  71540227.33
# 31 Minas Gerais       971394.37 2861781.50  ... 135977571.87 120467187.34
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 21 Maranhão           385330.18 1018352.93  ...  31128144.66  24374205.15
# 52 Goiás              179395.82  418053.58  ...  34437633.20  33499284.38
# 32 Espírito Santo      57408.11  284224.80  ...  27450865.16  27460475.47
#
# [7 rows x 156 columns]

# %%
#Desafio: adicionar uma coluna mostrando a região de cada estado

# regions_map = {'1': 'Norte', '2': 'Nordeste', '3': 'Sudeste', '4': 'Sul', '5': 'Centro-Oeste'}

# def aplica_mapa(i):
#     return regions_map[i[0]]

# usaveis.index.map(aplica_mapa)
# usaveis.index.map(lambda i: regions_map[i[0]])

# %%
#Criando numeros aleatorios usando uma seed com numpy

import numpy as np
np.random.seed(687942)

usaveis.sample(n  = 7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27450865.16  27460475.47
# 31 Minas Gerais        971394.37 2861781.50  ... 135977571.87 120467187.34
# 24 Rio Grande do Norte 134605.36  272088.08  ...  20219961.81  19593057.45
# 17 Tocantins             4113.76   76633.06  ...   5018138.13   4489665.87
# 53 Distrito Federal    191951.47  769966.25  ...  23479773.03  22233542.26
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  15838659.34  12508717.35
# 16 Amapá                33672.74  104822.98  ...   2699492.23   2155083.37
#
# [7 rows x 156 columns]

# %%
#Fazendo a soma de uma linha;
#Lembre-se que a função sum sem o parâmetro somaria a coluna e não a linha.

usaveis.sum(axis = 1)
# Out:
# Unidade da Federação
# 11 Rondônia                925572673.82
# 12 Acre                    420666755.81
# 13 Amazonas               1766925554.09
# 14 Roraima                 303485991.45
# 15 Pará                   4425537480.57
# 16 Amapá                   290781699.72
# 17 Tocantins               997507241.35
# 21 Maranhão               3621885105.60
# 22 Piauí                  2122676207.29
# 23 Ceará                  6182786402.04
# 24 Rio Grande do Norte    2469235766.39
# 25 Paraíba                2461941658.63
# 26 Pernambuco             8013135105.77
# 27 Alagoas                2097903424.04
# 28 Sergipe                1128585323.09
# 29 Bahia                  9167733691.21
# 31 Minas Gerais          19102100731.94
# 32 Espírito Santo         3128353199.69
# 33 Rio de Janeiro         9659938007.12
# 35 São Paulo             38779063638.12
# 41 Paraná                13745248985.60
# 42 Santa Catarina         7306969709.51
# 43 Rio Grande do Sul     11930181093.98
# ...

# %%
#Criando uma coluna com o total por estado

usaveis["Total"] = usaveis.sum(axis = 1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  925572673.82
# 12 Acre               10470.07  14001.71  ...  1163813.08  420666755.81
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1766925554.09
# 14 Roraima             4785.91  11858.63  ...  2739498.41  303485991.45
# 15 Pará              181159.29 433414.74  ... 27618727.51 4425537480.57
#
# [5 rows x 157 columns]

# %%
#Ordenando pelo total utilizando a coluna total 
#em ordem decrescente (ascending = False, já que por padrão é True).

ordenado_por_total = usaveis.sort_values(by = "Total", ascending = False)

#Já que temos a ordenação, podemos excluir a coluna total agora.

ordenado_por_total = ordenado_por_total.drop("Total", axis = 1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 31 Minas Gerais       971394.37 2861781.50  ... 135977571.87 120467187.34
# 41 Paraná             554800.22 1431708.01  ...  92901461.36  80320852.69
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  89019478.82  78929703.81
# 33 Rio de Janeiro     469469.34  921646.57  ...  77604925.21  71540227.33
#
# [5 rows x 156 columns]

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
#Porém, percebe-se uma anormalidade nos dados de janeiro de 2008,provavelmente
#dados viciados (adicionados todos em uma data);
#Vamos cortá-los então, pegando os dados da sexta coluna em diante.

colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
#Mudando as informações da coluna para deixar em milhões

ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
#Começando a analisar valores para os 3 primeiros que mais gastaram a partir de 2012 até mai/2020.
#No caso 2012 se da a partir da linha 47 e mai/2020 se da a partir da linha 150.

meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

#Porém, note que o gráfico está distorcido já que são paulo mostra um resultado
#4 vezes maior de gasto. Esté é o perigo de mudar os campos do gráfico (criar ilusões).

# %%
#Fazendo o mesmo gráfico anterior mas não distorcendo o campo visual (para não
#distorcer a realidade como no gráfico anterior);
#Faremos isso com o y limite (usando de 0 reais a 350 milhoes).

meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(00, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# # AULA 04 MOD 01
# -Análise de gráficos e criação de hipótese

# %% [markdown]
# Como mostrado nos últimos códigos do módulo 3, é necessário tomar cuidado com as escalas e escolhas de trechos para se mostrar em um gráfico, já que eles contam uma história, podendo escolher caminhos pré determinados de pensamentos para manipular pessoas, por exemplo.

# %%
#Diminuindo o figsize do gráfico para criar ilusões
#Dá-se a sensação de que a curva de crescimento é mais rápida do que realmente é
#O contrário aconteceria caso fosse um figsize de(20,6).
ordenado_por_total.head(5).T.plot(figsize=(6,6))

# %% [markdown]
# Um exemplo disso foi o período de pré pandemia no Brasil, onde pessoas escolhiam 7 paisés específicos para se comparar com o Brasil e dar a sensação (ilusão) de que estaria tudo tranquilo por aqui.
#
# O ideal seria ter escolhido países com uma população semelhante à do Brasil, com temperaturas parecidas por exemplo (onde pessoas saiam de casa no inverno, diferente de países nevados), etc.

# %% [markdown]
# # AULA 05 MOD 01
# -Manipulação e interpretação de gráficos

# %% [markdown]
# Lembre-se que como se utiliza um dataset variável, os dados podem se alterar com o tempo já que alguns dados de pacientes atendidos em julho, por exemplo, só serão computados meses depois (adicionando os dados em julho posteriormente).

# %%
#Pegando os últimos meses do ordenado por total
# -1 é o último mês, -2 seria o penúltimo mês, por exemplo.
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_ultimo_mes = ordenado_por_total[mes_mais_recente]
gastos_do_ultimo_mes.head()
# Out:
# Unidade da Federação
# 35 São Paulo           282.71
# 31 Minas Gerais        120.47
# 41 Paraná               80.32
# 43 Rio Grande do Sul    78.93
# 33 Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
#Plotando

gastos_do_ultimo_mes.plot()

# %%
#Plotando um gráfico de pizza (não aconselhável)

#Se tem nome de alimento não utilize

#No caso deste gráfico:
#Legenda ruim
#Número de fatias muito grande
#Cores repetidas
#Ruim para fazer comparação
#Gráfico veio ordenado (vantagem)    // para não ordenar utiliza-se .sample(frac=1)

gastos_do_ultimo_mes.plot(kind='pie')

# %%
#Visualização simples para valor absoluto

#Que no caso é ruim de se ver no gráfico da pizza

gastos_do_ultimo_mes
# Out:
# Unidade da Federação
# 35 São Paulo             282.71
# 31 Minas Gerais          120.47
# 41 Paraná                 80.32
# 43 Rio Grande do Sul      78.93
# 33 Rio de Janeiro         71.54
# 29 Bahia                  58.90
# 26 Pernambuco             62.33
# 42 Santa Catarina         51.76
# 23 Ceará                  30.81
# 52 Goiás                  33.50
# 15 Pará                   27.62
# 21 Maranhão               24.37
# 32 Espírito Santo         27.46
# 24 Rio Grande do Norte    19.59
# 25 Paraíba                15.49
# 53 Distrito Federal       22.23
# 50 Mato Grosso do Sul     12.51
# 22 Piauí                  18.02
# 27 Alagoas                13.09
# 51 Mato Grosso            13.08
# 13 Amazonas               13.36
# 28 Sergipe                 3.31
# 17 Tocantins               4.49
# 11 Rondônia                7.41
# 12 Acre                    1.16
# 14 Roraima                 2.74
# 16 Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
#Comparando a porcentagem de gastos do RJ com os demais
#Utiliza-se o .loc para tratar as linhas (buscar o valor da linha)

gastos_do_ultimo_mes / gastos_do_ultimo_mes.loc["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.95
# 31 Minas Gerais          1.68
# 41 Paraná                1.12
# 43 Rio Grande do Sul     1.10
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.82
# 26 Pernambuco            0.87
# 42 Santa Catarina        0.72
# 23 Ceará                 0.43
# 52 Goiás                 0.47
# 15 Pará                  0.39
# 21 Maranhão              0.34
# 32 Espírito Santo        0.38
# 24 Rio Grande do Norte   0.27
# 25 Paraíba               0.22
# 53 Distrito Federal      0.31
# 50 Mato Grosso do Sul    0.17
# 22 Piauí                 0.25
# 27 Alagoas               0.18
# 51 Mato Grosso           0.18
# 13 Amazonas              0.19
# 28 Sergipe               0.05
# 17 Tocantins             0.06
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.04
# 16 Amapá                 0.03
# Name: 2020/Jul, dtype: float64

# %%
#Desafio: Colocando grid no gráfico

gastos_do_ultimo_mes.plot(kind='bar')
plt.grid(True)

# %%
#Salvando os dados no google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # AULA 01 MOD 02
# -Fontes externas, limpeza e manipulação de dados

# %% [markdown]
# "Tudo que é absoluto, desconsidera a relatividade do mundo." Um exemplo disso é o gasto de são paulo 4 vezes maior em relação a outro estado, porém, são paulo tem 4 vezes mais habitantes que este outro estado, logo, o gasto per capita foi igual.

# %%
#Buscando os dados novamente mas utilizando um link com os dados desta vez

dados = pd.read_csv("https://raw.githubusercontent.com/GuilhermeRuy97/Estudos-DataScience/main/dados/A160324189_28_143_208.csv", encoding = "ISO-8859-1",
                    skiprows = 3, sep = ";", skipfooter = 12,
                    thousands = ".", decimal = ",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
#No caso, este é um gráfico absoluto e não relativo
gastos_do_ultimo_mes = gastos_do_ultimo_mes.sort_values(ascending = False)
gastos_do_ultimo_mes.plot(kind='bar')

# %%
#Gasto total do brasil
gastos_do_ultimo_mes.sum()

#Gasto proporcional por estado
#Neste ex, SP gastou cerca de 26% do total de gastos
#Agora, precisamos ver o número de habitantes, idade da população (idosos tem custo maior)
# entre outros índices, para relativizar e deixar a comparação justa
gastos_proporcionais = gastos_do_ultimo_mes / gastos_do_ultimo_mes.sum()
gastos_proporcionais.plot(kind='bar')

# %%
#Lendo arquivos do excel

ibge_estimativa = pd.read_excel("https://github.com/alura-cursos/agendamento-hospitalar/raw/main/dados/estimativa_dou_2020.xls")
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  ...          Unnamed: 2
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO                                                                  ...  POPULAÇÃO ESTIMADA
# 1                                             Brasil                                                                  ...           211755692
# 2                                       Região Norte                                                                  ...            18672591
# 3                                           Rondônia                                                                  ...             1796460
# 4                                               Acre                                                                  ...              894470
#
# [5 rows x 3 columns]

# %%
#Copiando os dados de uma tabela direito do wikipedia
#fonte: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o
#Uma string em python não pega multilinhas, logo, usa-se 3 aspas

dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 292 666	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 252 502	3,4%	 Sérvia (7 114 393)
11	 Maranhão	7 114 598	3,4%	 Paraguai (7 003 406)
12	 Goiás	7 113 540	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 207 714	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958) """

# %%
#O arquivo acima é similar a um csv, mas separado por tab
#O csv também comporta uma entrada de dados, usa-se a biblioteca io

from io import StringIO

dados_da_populacao_io = StringIO(dados_da_populacao)  #criando um leitor

populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
populacao = populacao.dropna()
populacao["populacao"] = populacao["População"].str.replace(" ", "").astype(int)
populacao["uf"] = populacao["Unidade federativa"]
populacao = populacao[["populacao", "uf"]].set_index("uf")
display(populacao.head())
display(populacao.info())

#-Neste caso, usa-se o display pois o .info() só mostra a ultima evaluation, logo,
#não mostraria o populacao.head()
#-A função display mostra o que esta entre parenteses
#-Usa-se a função .dropna() para tirar os NA's (linhas vazias) da tabela
#-"Arranca-se" os espaços com a função .str.replace(), com argumentos para trocar o espaço por nada
#sendo o .str para trabalhar com strings
# Out:
#                  populacao
# uf
#  São Paulo        46289333
#  Minas Gerais     21292666
#  Rio de Janeiro   17366189
# Bahia Bahia       14930634
#  Paraná           11516840
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries,  São Paulo to  Roraima
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   populacao  27 non-null     int64
# dtypes: int64(1)
# memory usage: 432.0+ bytes
# None

# %%
#Fazendo um slice
populacao.index.str[:3]
# Out:
# Index([' Sã', ' Mi', ' Ri', 'Bah', ' Pa', ' Ri', ' Pe', ' Ce', 'Par', ' Sa',
#        ' Ma', ' Go', ' Am', ' Es', ' Pa', ' Ri', ' Ma', ' Al', ' Pi', ' Di',
#        ' Ma', ' Se', ' Ro', ' To', ' Ac', ' Am', ' Ro'],
#       dtype='object', name='uf')

# %%
#Juntando populacao e gastos mais recentes

populacao.join(gastos_do_ultimo_mes)
# Out:
#                       populacao  2020/Jul
# uf
#  São Paulo             46289333       nan
#  Minas Gerais          21292666       nan
#  Rio de Janeiro        17366189       nan
# Bahia Bahia            14930634       nan
#  Paraná                11516840       nan
#  Rio Grande do Sul     11422973       nan
#  Pernambuco             9616621       nan
#  Ceará                  9187103       nan
# Pará Pará               8690745       nan
#  Santa Catarina         7252502       nan
#  Maranhão               7114598       nan
#  Goiás                  7113540       nan
#  Amazonas               4207714       nan
#  Espírito Santo         4064052       nan
#  Paraíba                4039277       nan
#  Rio Grande do Norte    3534165       nan
#  Mato Grosso            3526220       nan
#  Alagoas                3351543       nan
#  Piauí                  3281480       nan
#  Distrito Federal       3055149       nan
#  Mato Grosso do Sul     2809394       nan
# ...

# %%
#Nota-se que ele não reconhece e apresenta nan
#Isto acontece pois o indice correto seria 35 São Paulo e não São Paulo
#Vamos tirar os números de índices

gastos_do_ultimo_mes.index = gastos_do_ultimo_mes.index.str[3:]
gastos_do_ultimo_mes
# Out:
# Unidade da Federação
# São Paulo             282.71
# Minas Gerais          120.47
# Paraná                 80.32
# Rio Grande do Sul      78.93
# Rio de Janeiro         71.54
# Pernambuco             62.33
# Bahia                  58.90
# Santa Catarina         51.76
# Goiás                  33.50
# Ceará                  30.81
# Pará                   27.62
# Espírito Santo         27.46
# Maranhão               24.37
# Distrito Federal       22.23
# Rio Grande do Norte    19.59
# Piauí                  18.02
# Paraíba                15.49
# Amazonas               13.36
# Alagoas                13.09
# Mato Grosso            13.08
# Mato Grosso do Sul     12.51
# Rondônia                7.41
# Tocantins               4.49
# Sergipe                 3.31
# Roraima                 2.74
# Amapá                   2.16
# Acre                    1.16
# Name: 2020/Jul, dtype: float64

# %%
#Outra tentativa de juntar populacao e gastos mais recentes

populacao.join(gastos_do_ultimo_mes).head()
# Out:
#                  populacao  2020/Jul
# uf
#  São Paulo        46289333       nan
#  Minas Gerais     21292666       nan
#  Rio de Janeiro   17366189       nan
# Bahia Bahia       14930634       nan
#  Paraná           11516840       nan

# %%
#Ainda não foi possível
#Vamos tentar conferir se os índices estão corretos buscando por são paulo

#comentando para que os outros códigos rodem
#populacao.loc["São Paulo"]

#Note como ele não encontra o indice

# %%
#Tentando buscar São Paulo pelo índice para tentar achar o erro

populacao.index[0]

#O problema era um espaço antes de São Paulo
# Out:
# ' São Paulo'

# %%
#Vamos então, tirar os espaços entre os índices com o .strip()
populacao.index[0].strip()

#Tirando para todos
populacao.index = populacao.index.str.strip()
display(populacao.head())

populacao.loc["São Paulo"]  #Note como agora ele encontra o valor
# Out:
#                 populacao
# uf
# São Paulo        46289333
# Minas Gerais     21292666
# Rio de Janeiro   17366189
# Bahia Bahia      14930634
# Paraná           11516840
# populacao    46289333
# Name: São Paulo, dtype: int64

# %%
#Tentando juntar os valores após corrigir os índices

populacao.join(gastos_do_ultimo_mes)

#Alguns índices apresentam problemas por terem ficados repetidos, como "Bahia Bahia"
#Era um problema no copy paste
# Out:
#                      populacao  2020/Jul
# uf
# São Paulo             46289333    282.71
# Minas Gerais          21292666    120.47
# Rio de Janeiro        17366189     71.54
# Bahia Bahia           14930634       nan
# Paraná                11516840     80.32
# Rio Grande do Sul     11422973     78.93
# Pernambuco             9616621     62.33
# Ceará                  9187103     30.81
# Pará Pará              8690745       nan
# Santa Catarina         7252502     51.76
# Maranhão               7114598     24.37
# Goiás                  7113540     33.50
# Amazonas               4207714     13.36
# Espírito Santo         4064052     27.46
# Paraíba                4039277     15.49
# Rio Grande do Norte    3534165     19.59
# Mato Grosso            3526220     13.08
# Alagoas                3351543     13.09
# Piauí                  3281480     18.02
# Distrito Federal       3055149     22.23
# Mato Grosso do Sul     2809394     12.51
# Sergipe                2318822      3.31
# ...

# %%
#faremos um loop para corrigir os estados duplicados para ficar unicos

for estado in gastos_do_ultimo_mes.index:
  #print(f"{estado} {estado} => {estado}")
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)

populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Maranhão', 'Goiás', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
#Nova tentativa após correção dos valores duplicados

populacao.join(gastos_do_ultimo_mes)
# Out:
#                      populacao  2020/Jul
# uf
# São Paulo             46289333    282.71
# Minas Gerais          21292666    120.47
# Rio de Janeiro        17366189     71.54
# Bahia                 14930634     58.90
# Paraná                11516840     80.32
# Rio Grande do Sul     11422973     78.93
# Pernambuco             9616621     62.33
# Ceará                  9187103     30.81
# Pará                   8690745     27.62
# Santa Catarina         7252502     51.76
# Maranhão               7114598     24.37
# Goiás                  7113540     33.50
# Amazonas               4207714     13.36
# Espírito Santo         4064052     27.46
# Paraíba                4039277     15.49
# Rio Grande do Norte    3534165     19.59
# Mato Grosso            3526220     13.08
# Alagoas                3351543     13.09
# Piauí                  3281480     18.02
# Distrito Federal       3055149     22.23
# Mato Grosso do Sul     2809394     12.51
# Sergipe                2318822      3.31
# ...

# %%
gastos_e_populacao_recente = populacao.join(gastos_do_ultimo_mes)
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul
# uf
# São Paulo        46289333    282.71
# Minas Gerais     21292666    120.47
# Rio de Janeiro   17366189     71.54
# Bahia            14930634     58.90
# Paraná           11516840     80.32

# %% [markdown]
# # AULA 02 MOD 02
# -Proporcionalidade e Seaborn

# %%
#Existem alguns gráficos ruins na vida real onde coisas que não tem relação de notação
#compartilham o mesmo eixo, como pessoas e gastos (uma em habitantes e outra em dinheiro)
#compartilhando o mesmo eixo Y (medida que não faz sentido para utilizar os 2 ao mesmo tempo)

gastos_e_populacao_recente["gastos"] = gastos_e_populacao_recente["2020/Jul"] * 1000000
gastos_e_populacao_recente[["gastos", "populacao"]].plot()

# %% [markdown]
# Pode acontecer de querermos mostrar a relação entre duas variáveis como por exemplo, quanto maior a população maior o gasto, porém, neste caso muitas vezes os valores passam a não importar tanto.
# No caso do gráfico acima, ele não consegue passar a informação de que são paulo tem um gasto por habitante próximo ao do rio grande do sul pois como a população é maior, o gráfico fica deturpado.

# %%
display(gastos_e_populacao_recente.loc[["Rio Grande do Sul", "São Paulo"]])

#gasto por habitante sao paulo
display(282709570.31 / 46289333)

#gasto por habitante rio grande do sul
display(78929703.81 / 11422973)
# Out:
#                    populacao  2020/Jul       gastos
# uf
# Rio Grande do Sul   11422973     78.93  78929703.81
# São Paulo           46289333    282.71 282709570.31
# 6.107445322446102
# 6.909733902899009

# %%
#Mostrando o gasto por habitante dos demais

gastos_e_populacao_recente["gasto_por_habitante"] = gastos_e_populacao_recente["gastos"] / gastos_e_populacao_recente["populacao"]
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul       gastos  gasto_por_habitante
# uf
# São Paulo        46289333    282.71 282709570.31                 6.11
# Minas Gerais     21292666    120.47 120467187.34                 5.66
# Rio de Janeiro   17366189     71.54  71540227.33                 4.12
# Bahia            14930634     58.90  58898100.40                 3.94
# Paraná           11516840     80.32  80320852.69                 6.97

# %%
#plotando o gráfico de barra dos gastos por habitante

gastos_e_populacao_recente["gasto_por_habitante"].plot(kind = 'bar')

#Com esse gráfico é possível notar que o estado com o maior gasto total não é
#o estado com o maior gasto por habitante

# %%
#Começando a trabalhar com o seaborn, utilizada para plots

import seaborn as sns

sns.scatterplot(data = gastos_e_populacao_recente / 1000000, x = "populacao", y = "gastos")

# %%
#plotando como um quadrado
plt.figure(figsize=(6,6))
sns.scatterplot(data = gastos_e_populacao_recente / 1000000, x = "populacao", y = "gastos")

#Nota-se uma espécie de reta entre os valores (proporção)

# %%
#Mesmo gráfico mas com gasto por habitante
plt.figure(figsize=(6,6))
sns.scatterplot(data = gastos_e_populacao_recente, x = "populacao", y = "gasto_por_habitante")

#Nota-se números espalhados, sem a mesma sensação de reta

# %% [markdown]
# ## A partir daqui utilizaremos função para refatorar o código acima

# %%
#Criando função para refatorar código

def insere_gastos_e_gasto_por_habitante_para(todos_os_gastos: pd.DataFrame, dados: pd.DataFrame, mes: str):
  gastos_do_mes = todos_os_gastos[mes]
  dados[f"gastos_{mes}"] = gastos_do_mes * 1000000
  dados[f"gasto_por_habitante_{mes}"] = dados[f"gastos_{mes}"] / dados["populacao"]

# %%
#Tirando os 3 primeiros caracteres para todos e não somente para os mais recentes

ordenado_por_total.index = ordenado_por_total.index.str[3:]

# %%
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Jul")
gastos_e_populacao_recente[["gastos_2020/Jul", "populacao"]].plot()

# %%
gastos_e_populacao_recente.loc[["Rio Grande do Sul", "São Paulo"]]
# Out:
#                    populacao  ...  gasto_por_habitante_2020/Jul
# uf                            ...
# Rio Grande do Sul   11422973  ...                          6.91
# São Paulo           46289333  ...                          6.11
#
# [2 rows x 6 columns]

# %%
gastos_e_populacao_recente.head()
# Out:
#                 populacao  ...  gasto_por_habitante_2020/Jul
# uf                         ...
# São Paulo        46289333  ...                          6.11
# Minas Gerais     21292666  ...                          5.66
# Rio de Janeiro   17366189  ...                          4.12
# Bahia            14930634  ...                          3.94
# Paraná           11516840  ...                          6.97
#
# [5 rows x 6 columns]

# %%
#plotando o gráfico de barra dos gastos por habitante depois de utilizar a função

gastos_e_populacao_recente["gasto_por_habitante_2020/Jul"].plot(kind = 'bar')

# %%
#Depois de utilizar a função

sns.scatterplot(data = gastos_e_populacao_recente / 1000000, x = "populacao", y = "gastos_2020/Jul")

# %%
#Já que agora temos a função que automatiza o processo, podemos chamar a mesma função de Julho para Junho

insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Jun")
gastos_e_populacao_recente.head()
# Out:
#                 populacao  ...  gasto_por_habitante_2020/Jun
# uf                         ...
# São Paulo        46289333  ...                          6.46
# Minas Gerais     21292666  ...                          6.39
# Rio de Janeiro   17366189  ...                          4.47
# Bahia            14930634  ...                          4.36
# Paraná           11516840  ...                          8.07
#
# [5 rows x 8 columns]

# %%
#Inserindo dados para maio

insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Mai")
gastos_e_populacao_recente.head()
# Out:
#                 populacao  ...  gasto_por_habitante_2020/Mai
# uf                         ...
# São Paulo        46289333  ...                          6.54
# Minas Gerais     21292666  ...                          6.43
# Rio de Janeiro   17366189  ...                          4.97
# Bahia            14930634  ...                          4.14
# Paraná           11516840  ...                          9.21
#
# [5 rows x 10 columns]

# %%
#Imprimindo os gráficos de  Mai, Jun e Jul de 2020 (nota-se que o seaborn plota as 3 vezes com cores distintas)

plt.figure(figsize=(6,6))
sns.scatterplot(data = gastos_e_populacao_recente / 1000000, x = "populacao", y = "gastos_2020/Jul")
sns.scatterplot(data = gastos_e_populacao_recente / 1000000, x = "populacao", y = "gastos_2020/Jun")
sns.scatterplot(data = gastos_e_populacao_recente / 1000000, x = "populacao", y = "gastos_2020/Mai")

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data = gastos_e_populacao_recente, x = "populacao", y = "gasto_por_habitante_2020/Jul")

# %%
plt.figure(figsize=(7,7))
sns.scatterplot( data = gastos_e_populacao_recente, x = "populacao", y = "gasto_por_habitante_2020/Mai")

# %% [markdown]
# # AULA 03 MOD 02
# -Ticks, escalas e formatação de imagem

# %%
#Lembrando que o ordenado por total é uma tabela que mostra o gasto por mês de uma unidade da federação

ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  ...  2020/Jun  2020/Jul
# Unidade da Federação                      ...
# São Paulo               172.83    170.48  ...    299.06    282.71
# Minas Gerais             70.30     79.12  ...    135.98    120.47
# Paraná                   48.86     55.61  ...     92.90     80.32
# Rio Grande do Sul        45.90     52.93  ...     89.02     78.93
# Rio de Janeiro           44.12     42.89  ...     77.60     71.54
#
# [5 rows x 150 columns]

# %%
#Montando um gráfico de minas gerais
#Note que como estamos passando todos os vlaores, não precisamos do parâmetro "data = ..."

sns.scatterplot(x = ordenado_por_total.columns, y = ordenado_por_total.loc["São Paulo"])

# %%
#Porém, o caso acima não é o uso tradicional do scatterplot
#Com a transposta da matriz do ordenado_por_total, os estados viram as colunas,
#logo, podemos utilizá-los para a forma mais correta do scatterplot

mensal = ordenado_por_total.T

display(mensal.head())

sns.scatterplot(data = mensal, x = mensal.index, y = "São Paulo")
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008/Fev                 172.83         70.30   48.86  ...  1.74     0.77   1.28
# 2008/Mar                 170.48         79.12   55.61  ...  2.06     0.88   1.18
# 2008/Abr                 170.28         79.05   56.12  ...  2.06     0.90   1.40
# 2008/Mai                 172.40         79.27   55.57  ...  2.23     1.03   1.41
# 2008/Jun                 175.42         79.61   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
#Os valores para o eixo X estavam ruins e com a legenda sobreposta

#Utilizando um gráfico de linhas com seaborn
sns.lineplot(data = mensal, x = mensal.index, y = "São Paulo")

# %%
#Ajustando a figura:
#Ajustando o tamanho
#Ajustando as legendas do eixo x (rotacionando a legenda em 30 graus)
#O auto locator faz automaticamente uma escolha dele de quais meses colocar automaticamente
#Procurar por "Tick Locators" no google caso queira mais exemplos e estilos
#Com o IndexLocator, conseguimos escolher por ex, para o eixo X mudar de 12 em 12 meses,
#com o começo sendo do 0

plt.figure(figsize=(10,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = "São Paulo")
plt.xticks(rotation = 30)
#ax.xaxis.set_major_locator(ticker.AutoLocator())
plt.ylim(0, 350)  #limitando o eixo y até 350
ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 0))
plt.grid(True, linestyle = "--")   #colocando grid e mudando o estilo do grid para tracejado
plt.show()

# %% [markdown]
# # AULA 04 MOD 02
# -Datas com Datetime e Melt

# %%
#trabalhando com data e hora no python
#Existe uma função na biblioteca datetime chamada de datetime

import datetime

datetime.datetime(2020, 11, 3)  #ano/mes/dia
# Out:
# datetime.datetime(2020, 11, 3, 0, 0)

# %%
#importando o dia atual

from datetime import date

date.today()
# Out:
# datetime.date(2021, 2, 18)

# %%
#Existe uma função que podemos aplicar a series onde pegamos o índice e aplicamos uma função

#Criando um dicionário para o meses
meses= {
    "Jan": 1,
    "Fev": 2,
    "Mar": 3,
    "Abr": 4,
    "Mai": 5,
    "Jun": 6,
    "Jul": 7,
    "Ago": 8,
    "Set": 9,
    "Out": 10,
    "Nov" : 11,
    "Dez" : 12
}

#função que transforma o mes em dia

def para_dia(ano_mes: str):
  ano: int = int(ano_mes[:4])    #caracter do ano são os ultimos 4 dígitos
  mes: str = ano_mes[5:]         #caracter do mes é a partir do quinto caracter
  mes_numero: int = meses[mes]
  return date(ano, mes_numero, 1)

#mapeando os valores para cada valor
mensal.index = mensal.index.map(para_dia)
mensal.head()

#Repare que o índice agora está como data e não mais uma string
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008-02-01               172.83         70.30   48.86  ...  1.74     0.77   1.28
# 2008-03-01               170.48         79.12   55.61  ...  2.06     0.88   1.18
# 2008-04-01               170.28         79.05   56.12  ...  2.06     0.90   1.40
# 2008-05-01               172.40         79.27   55.57  ...  2.23     1.03   1.41
# 2008-06-01               175.42         79.61   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal, x=mensal.index, y="São Paulo")
plt.xticks(rotation=30)
plt.ylim(0, 350)
plt.grid(linestyle="--")
plt.show()

#repare como ele automaticamente coloca os anos e marca nos janeiros agora

# %%
#Vendo os tipos das colunas

display(mensal.info())

#repare como o indice é uma data de 2008-02-01 a 2020-07-01
#pois, como agora temos uma data ao invés de uma string, o próprio compilador
#consegue fazer um melhor "locator" automático

display(mensal.index[0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 2008-02-01 to 2020-07-01
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   São Paulo            150 non-null    float64
#  1   Minas Gerais         150 non-null    float64
#  2   Paraná               150 non-null    float64
#  3   Rio Grande do Sul    150 non-null    float64
#  4   Rio de Janeiro       150 non-null    float64
#  5   Bahia                150 non-null    float64
#  6   Pernambuco           150 non-null    float64
#  7   Santa Catarina       150 non-null    float64
#  8   Ceará                150 non-null    float64
#  9   Goiás                150 non-null    float64
#  10  Pará                 150 non-null    float64
#  11  Maranhão             150 non-null    float64
#  12  Espírito Santo       150 non-null    float64
#  13  Rio Grande do Norte  150 non-null    float64
# ...

# %%
#Vamos agora plotar o gráfico para todos os estados
#Primeiro resetamos o indice
#Com o .met() , "derretemos" os estados separadamente e dizemos como parâmetro quem não queremos derreter
#Falamos então que queremos manter a coluna de data, que se chama index
#Forçamos uma ordem passando os estados na ordem em que aparecem
#Transformamos o mensal_aberto em uma data com o .astype('datetime64')

mensal_aberto = mensal.reset_index().melt(id_vars = ["index"], value_vars = mensal.columns)
mensal_aberto.columns = ["dia_mes_ano", "uf", "gasto"]    #trocando os nomes das colunas
mensal_aberto["dia_mes_ano"] = mensal_aberto["dia_mes_ano"].astype('datetime64')
mensal_aberto
# Out:
#      dia_mes_ano         uf  gasto
# 0     2008-02-01  São Paulo 172.83
# 1     2008-03-01  São Paulo 170.48
# 2     2008-04-01  São Paulo 170.28
# 3     2008-05-01  São Paulo 172.40
# 4     2008-06-01  São Paulo 175.42
# ...          ...        ...    ...
# 4045  2020-03-01      Amapá   2.29
# 4046  2020-04-01      Amapá   1.77
# 4047  2020-05-01      Amapá   2.70
# 4048  2020-06-01      Amapá   2.70
# 4049  2020-07-01      Amapá   2.16
#
# [4050 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data = mensal_aberto, x = "dia_mes_ano", y = "gasto")
plt.xticks(rotation = 30)
plt.ylim(0, 350)
plt.grid(linestyle = "--")
plt.show()

#A linha azul é a média de valores e a faixa é o intervalo de confiança

# %%
#agrupando por uf utilizando o hue

plt.figure(figsize=(10,6))
ax = sns.lineplot(data = mensal_aberto, x = "dia_mes_ano", y = "gasto", hue = "uf")
plt.xticks(rotation = 30)
plt.ylim(0, 350)
plt.grid(linestyle = "--")
plt.show()

# %% [markdown]
# # AULA 05 MOD 02
# -Manipulando data e gerando novas análises

# %%
#Criando uma variável para o mês a partir da variável dia_mes_ano
mensal_aberto["mes"] = mensal_aberto["dia_mes_ano"].dt.month
mensal_aberto["ano"] = mensal_aberto["dia_mes_ano"].dt.year

mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano
# 0  2008-02-01  São Paulo 172.83    2  2008
# 1  2008-03-01  São Paulo 170.48    3  2008
# 2  2008-04-01  São Paulo 170.28    4  2008
# 3  2008-05-01  São Paulo 172.40    5  2008
# 4  2008-06-01  São Paulo 175.42    6  2008

# %%
#Podemos comparar os anos também, criando uma linha para cada ano
#Fazemos uma query para pegar somente o estado de SP em vez de todos


plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"), x="mes", y="gasto", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 350)
plt.grid(linestyle="--")
plt.show()

# %%
#Vendo quantos dias tem em um mês com um dicionário

dias_por_mes = {
    1 : 31,
    2 : 28,
    3 : 31,
    4 : 30,
    5 : 31,
    6 : 30,
    7 : 31,
    8 : 31,
    9 : 30,
    10 : 31,
    11 : 30,
    12 : 31
}

# %%
#Descobrindo o gasto diário agora

mensal_aberto['gasto_diario'] = mensal_aberto['gasto'] / mensal_aberto['mes'].map(dias_por_mes)
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008          5.85

# %%
#Gráfico de SP para o gasto diário

plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"), x="mes", y="gasto_diario", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 12)
plt.grid(linestyle="--")
plt.show()

# %%
#Mesmo gráfico para o Rio de Janeiro

plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='Rio de Janeiro'"), x="mes", y="gasto_diario", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 12)
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# # AULA 06 MOD 02
# -Agrupando dados e analisando por categoria

# %%
estado_a_analisar = mensal_aberto.query("uf == 'São Paulo'")
estado_a_analisar.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008          5.85

# %%
#Podemos analisar pelo ano e utilizar o .sum() para somar o gasto (repare que ele soma o mês tbm)

gastos_por_ano = estado_a_analisar.groupby("ano").sum()
gastos_por_ano.head()
# Out:
#        gasto  mes  gasto_diario
# ano
# 2008 1960.23   77         64.60
# 2009 2489.03   78         81.82
# 2010 2696.62   78         88.63
# 2011 2794.55   78         91.91
# 2012 2873.97   78         94.47

# %%
#Lembrando que não existe uma coluna índice, é necessário passar o eixo

sns.scatterplot(data = gastos_por_ano, x = gastos_por_ano.index, y = 'gasto')

#Necessario arrumar o limite em y

# %%
#Criando o gráfico de linha

sns.lineplot(data = gastos_por_ano, x = gastos_por_ano.index, y = 'gasto')

# %%
#Criando o gráfico de barras
#Procurar por seaborn paletes de cores
#seaborn.pydata.org/tutorial/color_palettes.html
#Falamos então que queremos 13 tons

sns.barplot(data = gastos_por_ano, x = gastos_por_ano.index, y = 'gasto', palette = sns.color_palette("rocket_r", 13))

#desafio: cor oredenada pelo valor em y

# %%
#escolhendo novos estados
#utilizamos os estados que estão em "estados"

estados = ["São Paulo", "Minas Gerais", "Pernambuco"]
por_ano_dos_estados = mensal_aberto.query("uf in @estados").groupby(["uf", "ano"]).sum().reset_index()
por_ano_dos_estados.head()
# Out:
#              uf   ano   gasto  mes  gasto_diario
# 0  Minas Gerais  2008  894.35   77         29.44
# 1  Minas Gerais  2009 1149.14   78         37.77
# 2  Minas Gerais  2010 1217.49   78         40.03
# 3  Minas Gerais  2011 1315.02   78         43.24
# 4  Minas Gerais  2012 1408.35   78         46.29

# %%
#Como para o mesmo ano ele tem 3 valores (SP, PE e MG) ele cria um intervalo de confiança

sns.barplot(data = por_ano_dos_estados, x = "ano", y = "gasto")

# %%
#Arrumando, dizendo que cada estado é uma barra diferente

sns.barplot(data = por_ano_dos_estados, x = "ano", y = "gasto", hue="uf")

# %%
#um plot por categoria
#Passamos que o tipo é de barra e que cada coluna "uf" é um gráfico diferente

sns.catplot(data = por_ano_dos_estados, y = "gasto", x = "ano", kind = "bar", col = "uf")

# %%
#mesmo gráfico porém em linha

sns.catplot(data = por_ano_dos_estados, y = "gasto", x = "ano", kind = "bar", row = "uf")

# %%
#Com a linha, conseguimos ver o crescimento mais facilmente

sns.lineplot(data = por_ano_dos_estados, y = "gasto", x = "ano", hue = "uf")

# %%
#Há varios tipos de catplot, pois ele é mais alto nível e abrange mais tipos, por ex:

sns.catplot(data = por_ano_dos_estados, y = "gasto", x = "ano", kind = "strip", col = "uf")

# %%
sns.catplot(data = por_ano_dos_estados, y = "gasto", x = "ano", kind = "violin", col = "uf")

# %%
#é possível fazer um catplot para um gráfico só também

sns.catplot(data = por_ano_dos_estados, y = "gasto", x = "ano", kind = "strip")

# %% [markdown]
# Existem vários tipos de plots que também agrupam plots, como é feito no catplot. Por exemplo:
# -Relational plots
# -Distribution plots
# -Categorial plots
# -Regression plots
# -Matrix plots
